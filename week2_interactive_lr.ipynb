# %% [markdown]
# ## Artificial Intelligence for Nanofabrication, Intro & Data Hands-On
# Hands-On: Linear Regression with spin-coating data
# ##### Sabah Gaznaghi, Joshua Soo, Monash University

# %% [markdown]
# Importing the required libraries

# %% [markdown]
# ##Teamwork 1
# Complete the import block

# %%
import pandas as
import
from sklearn
from

# %% [markdown]
# And now we need to import libraries for the metrics

# %% [markdown]
# Loading the dataset based on the format

# %%
# Load data (Excell file) as a DataFrame
df = pd.read

# Define the X and y variables

y =
X =

#print the shape of the data


# print 6 first rows of the DataFrame

# %% [markdown]
# ## Teamwork 2
#
# Use ***`describe`*** method and see what information it provides you with? How it is different from ***`head`*** method?

# %%
# Your answer here
print

# %% [markdown]
# Split dataset into train and test sets.

# %%
# Splitting dataset? why?

# %% [markdown]
# **Question 1**. What is the SHAPE of your X_train set?

# %% [markdown]
# Build a linear regression model. (we did not split the dataset here.)

# %%
# Train model
model =

# %% [markdown]
# ## Teamwork 3
#
# 1. Create your metrics
# 2. Calculate LR coeffient and intercept
# 3. Print your results in separate lines

# %%
# define the prediction output
y_pred = model.predict(X_test)

# Create metrics and calculate your LR model coefficient and intercept.
# Next print the results in a separate line
mae =
r2 =

coef = model.coef_[0]
intercept = model.intercept_

print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2) Score:", r2)
print("Coefficient (slope):", coef)
print("Intercept:", intercept)

# %% [markdown]
# Using the trained model for predictions.

# %%
# Predict new values
new_speeds = pd.DataFrame({'spin_speed_rpm': [1000, 2000, 2500]})
print('Predicted thickness (nm):', model.predict(new_speeds).round(1))

# %% [markdown]
# **Question 2**. What is round() in the previous code block and what does round (1) do there?

# %% [markdown]
# ## Visualise the results
# **Question 3**. What does the slope represent?

# %%
# Plot fit (scatter plot)
plt.scatter(X, y, s=10, label='Data')
plt.plot(X, model.predict(X), color='k', label='Fit')

# add axis labels


# add title and legend
plt.
plt.

plt.tight_layout()
# save your plot
plt.savefig('week10_fit.png')
